# %%
#Import library
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %matplotlib inline

# %%
#Reading excel file
data = pd.read_csv("C:/Users/Bhavik/Desktop/Data Science/1. Linear Regression/bigmart_data.csv")
#encoding= 'unicode_escape'

# %%
price_by_item = data.groupby('Item_Type').Item_MRP.mean()[:10]
price_by_item
# Out:
# Item_Type
# Baking Goods             126.380766
# Breads                   140.952669
# Breakfast                141.788151
# Canned                   139.763832
# Dairy                    148.499208
# Frozen Foods             138.503366
# Fruits and Vegetables    144.581235
# Hard Drinks              137.077928
# Health and Hygiene       130.818921
# Household                149.424753
# Name: Item_MRP, dtype: float64

# %%
price_by_item = data.groupby('Item_Type').Item_MRP.mean()[:10]

x = price_by_item.index.tolist()
y = price_by_item.values.tolist()

plt.figure(figsize = (14,8))

plt.title('Mean price for each item type')

plt.xlabel('Item Type')
plt.ylabel('Mean Price')

plt.xticks(labels = x, ticks = np.arange(len(x)))

plt.plot(x,y)

# %%
sales_by_outlet_size = data.groupby('Outlet_Size').Item_Outlet_Sales.mean()

sales_by_outlet_size.sort_values(inplace = True)

x = sales_by_outlet_size.index.tolist()
y = sales_by_outlet_size.values.tolist()

plt.xlabel('Outlet_Size')
plt.ylabel('Sales')

plt.title('Mean sales for each outlet size')

plt.xticks(labels=x, ticks=np.arange(len(x)))

plt.bar(x,y,color = ['red', 'orange', 'magenta'])
# Out:
# <BarContainer object of 3 artists>

# %%
data.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
plt.title('Item MRP Distribution')

plt.xlabel('Item_MRP')

plt.ylabel('Frequency')

plt.hist(data['Item_MRP'], bins = 20, color = 'lightblue')
# Out:
# (array([451., 472., 415., 158., 477., 576., 620., 628., 295., 509., 580.,
#         518., 622., 578., 227., 253., 303., 254., 271., 316.]),
#  array([ 31.29   ,  43.06992,  54.84984,  66.62976,  78.40968,  90.1896 ,
#         101.96952, 113.74944, 125.52936, 137.30928, 149.0892 , 160.86912,
#         172.64904, 184.42896, 196.20888, 207.9888 , 219.76872, 231.54864,
#         243.32856, 255.10848, 266.8884 ]),
#  <a list of 20 Patch objects>)

# %%
data_BM = data[['Item_Outlet_Sales']]

red_diamond = dict(markerfacecolor = 'r', marker = 'D')

plt.title('Item Sales Distribution')

plt.boxplot(data_BM.values, labels = ['Item Sales'], flierprops = red_diamond);

# %%
data_BM = data[['Item_Weight', 'Item_MRP']]

red_diamond = dict(markerfacecolor = 'r', marker = 'D')

fig, ax = plt.subplots()

plt.boxplot(data_BM.values, labels = ['Item Weight', 'Item MRP (price)']);
# Out:
# C:\Users\Bhavik\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1239: RuntimeWarning: invalid value encountered in less_equal
#   wiskhi = x[x <= hival]
# C:\Users\Bhavik\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1246: RuntimeWarning: invalid value encountered in greater_equal
#   wisklo = x[x >= loval]
# C:\Users\Bhavik\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1254: RuntimeWarning: invalid value encountered in less
#   x[x < stats['whislo']],
# C:\Users\Bhavik\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1255: RuntimeWarning: invalid value encountered in greater
#   x[x > stats['whishi']],

# %%
data_BM = data[['Item_Weight', 'Item_MRP']]

fig, ax = plt.subplots()

plt.xticks(ticks = [1,2], labels = ['Item Weight', 'Item MRP'])

plt.violinplot(data_BM.values);
# Out:
# C:\Users\Bhavik\anaconda3\lib\site-packages\numpy\linalg\linalg.py:2116: RuntimeWarning: invalid value encountered in det
#   r = _umath_linalg.det(a, signature=signature)

# %%
plt.xlabel('Item_Weight')
plt.ylabel('Item_Visibility')

plt.scatter(data['Item_Weight'][:200], data["Item_Visibility"][:200])

# %%
plt.xlabel('Item_MRP')
plt.ylabel('Item_Outlet_Sales')

plt.title('Item Outlet Sales vs Item MRP (Price)')

plt.scatter(data['Item_MRP'][:100], data['Item_Outlet_Sales'][:100], s = data['Item_Visibility'][:100]*1000, c = 'red')
