# %%
#Import library
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline #Display plots in the notebook itself
# Out:
# UsageError: unrecognized arguments: #Display plots in the notebook itself

# %%
#Creating data
height = [150, 160, 165, 185]
weight = [70, 80, 90, 100]

#Drawing line plot
plt.plot(height, weight)
#Adding title
plt.title("Relationship between height and weight")
#Adding X axis label
plt.xlabel("Height")
#Adding Y axis label
plt.ylabel("Weight")
# Out:
# Text(0, 0.5, 'Weight')

# %%
calories_burnt = [65, 75, 95, 99]

plt.plot(calories_burnt);

plt.plot(weight);

# %%
plt.plot(calories_burnt)
plt.plot(weight)

plt.legend(labels = ['Calories_Burnt', 'Weight'], loc = 'lower right')

plt.xticks(ticks = [0,1,2,3], labels = ['p1', 'p2', 'p3', 'p4']);

# %%
plt.figure(figsize = (15,5))

plt.plot(calories_burnt)
plt.plot(weight)

plt.legend(labels = ['Calories_Burnt', 'Weight'], loc = 'lower right')

plt.xticks(ticks = [0,1,2,3], labels = ['p1', 'p2', 'p3', 'p4']);

# %%
plt.plot(calories_burnt)
plt.plot(weight, 'y--')

plt.legend(labels = ['Calories Burnt', 'Weight'], loc = 'lower right')

plt.xticks(ticks = [0,1,2,3], labels = ['p1', 'p2', 'p3', 'p4']);

# %%
plt.plot(calories_burnt, 'bo')
plt.plot(weight, 'y--')

plt.legend(labels = ['Calories Burnt', 'Weight'], loc = 'lower right')

plt.xticks(ticks = [0,1,2,3], labels = ['p1', 'p2', 'p3', 'p4']);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-d4a8f39f4bce> in <module>
# ----> 1 plt.plot(calories_burnt, 'bo')
#       2 plt.plot(weight, 'y--')
#       3
#       4 plt.legend(labels = ['Calories Burnt', 'Weight'], loc = 'lower right')
#       5
#
# NameError: name 'calories_burnt' is not defined

# %%
fig, ax = plt.subplots(nrows = 2, ncols = 2, figsize = (6,6))

ax[0,0].plot(calories_burnt, 'go')

ax[0,1].plot(weight)

ax[0,0].set_title("Calories Burnt")
ax[0,1].set_title("Weight")

ax[0,0].set_xticks(ticks = [0,1,2,3]);
ax[0,1].set_xticks(ticks = [0,1,2,3]);

ax[0,0].set_xticklabels(labels = ['p1', 'p2', 'p3', 'p4']);
ax[0,1].set_xticklabels(labels = ['p1', 'p2', 'p3', 'p4']);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-24543bb0a591> in <module>
#       1 fig, ax = plt.subplots(nrows = 2, ncols = 2, figsize = (6,6))
#       2
# ----> 3 ax[0,0].plot(calories_burnt, 'go')
#       4
#       5 ax[0,1].plot(weight)
#
# NameError: name 'calories_burnt' is not defined

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 2, figsize = (6,6), sharey = True)

ax[0].plot(calories_burnt, 'go')

ax[1].plot(weight)

ax[0].set_title("Calories Burnt")
ax[1].set_title("Weight")

ax[0].set_xticks(ticks = [0,1,2,3]);
ax[1].set_xticks(ticks = [0,1,2,3]);

ax[0].set_xticklabels(labels = ['p1', 'p2', 'p3', 'p4']);
ax[1].set_xticklabels(labels = ['p1', 'p2', 'p3', 'p4']);
