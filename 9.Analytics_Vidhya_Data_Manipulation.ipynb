# %%
#Importing libraries
import pandas as pd
import numpy as np

# %%
#Reading csv file
data = pd.read_csv("C:/Users/Bhavik/Desktop/Data Science/1. Linear Regression/3_Insurance_Losses/InsuranceLosses.csv")

# %%
#Drop the null values
data = data.dropna(how = "any")

# %%
#View top five data
data.head()
# Out:
#    Policy Number  Age  Years of Driving Experience  Number of Vehicles Gender  \
# 0         150024   24                            5                   1      M
# 1         144880   31                           10                   1      F
# 2         133742   56                           37                   1      M
# 3         151282   52                           31                   1      F
# 4         174407   20                            3                   1      M
#
#    Married  Vehicle Age Fuel Type      Losses
# 0  Married           11         P  203.319595
# 1   Single            6         P  402.197302
# 2  Married            0         D  553.132096
# 3  Married           15         P  292.430579
# 4   Single           15         P  246.540576

# %%
#Sorting the data(By default ascending order)
sorted_data = data.sort_values(by = "Losses")

#View the sorted data
sorted_data[:5]
# Out:
#        Policy Number  Age  Years of Driving Experience  Number of Vehicles  \
# 11180         144717   64                           46                   3
# 13657         168897   67                           49                   4
# 14931         168101   65                           45                   4
# 3352          183044   63                           45                   2
# 13514         177232   67                           49                   4
#
#       Gender  Married  Vehicle Age Fuel Type     Losses
# 11180      F  Married           11         P  12.534521
# 13657      M  Married           12         P  12.614093
# 14931      F  Married           15         P  13.290628
# 3352       F  Married           12         P  13.901110
# 13514      F  Married           12         P  14.860606

# %%
#Sorting data in descending order
sorted_data_dis = data.sort_values(by = "Losses", ascending=False)

#View the data
sorted_data_dis[:5]
# Out:
#        Policy Number  Age  Years of Driving Experience  Number of Vehicles  \
# 101           147805   25                            8                   1
# 109           122992   50                           32                   1
# 7240          143824   20                            1                   2
# 12706         174360   16                            0                   3
# 110           110488   35                           15                   1
#
#       Gender Married  Vehicle Age Fuel Type       Losses
# 101        M  Single            5         D  3500.000000
# 109        F  Single           15         P  3462.340629
# 7240       M  Single            3         D  3462.000000
# 12706      M  Single            4         D  3333.000000
# 110        M  Single            9         P  3332.771801

# %%
#Sorting discending order of two column data
sorted_data_dis1 = data.sort_values(by = ["Losses","Vehicle Age"], ascending=False)

#View the data
sorted_data_dis1[:5]
# Out:
#        Policy Number  Age  Years of Driving Experience  Number of Vehicles  \
# 101           147805   25                            8                   1
# 109           122992   50                           32                   1
# 7240          143824   20                            1                   2
# 12706         174360   16                            0                   3
# 110           110488   35                           15                   1
#
#       Gender Married  Vehicle Age Fuel Type       Losses
# 101        M  Single            5         D  3500.000000
# 109        F  Single           15         P  3462.340629
# 7240       M  Single            3         D  3462.000000
# 12706      M  Single            4         D  3333.000000
# 110        M  Single            9         P  3332.771801

# %%
#Sorting discending order of two column data
sorted_data_dis1 = data.sort_values(by = ["Vehicle Age","Losses"], ascending=False)

#View the data
sorted_data_dis1[:5]
# Out:
#        Policy Number  Age  Years of Driving Experience  Number of Vehicles  \
# 109           122992   50                           32                   1
# 102           190621   16                            0                   1
# 10202         177159   16                            0                   3
# 9005          190271   17                            0                   3
# 11992         141554   18                            0                   3
#
#       Gender Married  Vehicle Age Fuel Type       Losses
# 109        F  Single           15         P  3462.340629
# 102        M  Single           15         P  3250.000000
# 10202      M  Single           15         D  1377.539259
# 9005       M  Single           15         D  1350.971873
# 11992      M  Single           15         D  1268.076011

# %%
#Sorting the data through index
sorted_data_indx = sorted_data_dis1.sort_index()

# %%
sorted_data_indx[:5]
# Out:
#    Policy Number  Age  Years of Driving Experience  Number of Vehicles Gender  \
# 0         150024   24                            5                   1      M
# 1         144880   31                           10                   1      F
# 2         133742   56                           37                   1      M
# 3         151282   52                           31                   1      F
# 4         174407   20                            3                   1      M
#
#    Married  Vehicle Age Fuel Type      Losses
# 0  Married           11         P  203.319595
# 1   Single            6         P  402.197302
# 2  Married            0         D  553.132096
# 3  Married           15         P  292.430579
# 4   Single           15         P  246.540576
